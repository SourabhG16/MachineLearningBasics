# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('pokemon.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 60.2+ KB

# %%
data.isnull().sum()
# Out:
# #               0
# Name            1
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
data.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.154336  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.012181    0.983428   0.154336
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
f,ax=plt.subplots(figsize=(12,8))
sns.heatmap(data.corr(),annot=True,ax=ax,linewidths=.2)
plt.show()

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data['Defense'].max()
# Out:
# 230

# %%
data.Speed.plot(kind='line',c='g',label='Speed',grid=True,linewidth=1,alpha=.5)
data.Defense.plot(kind='line',c='r',label='Defense',grid=True,linewidth=1,alpha=.5)
plt.legend(loc='upper right')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line plot')
plt.show()

# %%
data.plot(kind='scatter',x='Attack',y='Defense')
plt.title('Attack Defense Scatter plot')
plt.show()

# %%
data.Speed.plot(kind='hist',bins=30)

# %%
series=data['Defense']

# %%
print(type(series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
series
# Out:
# 0       49
# 1       63
# 2       83
# 3      123
# 4       43
#       ...
# 795    150
# 796    110
# 797     60
# 798     60
# 799    120
# Name: Defense, Length: 800, dtype: int64

# %%
dataframe=data[['Defense']]

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe
# Out:
#      Defense
# 0         49
# 1         63
# 2         83
# 3        123
# 4         43
# ..       ...
# 795      150
# 796      110
# 797       60
# 798       60
# 799      120
#
# [800 rows x 1 columns]

# %%
x=dataframe['Defense']>200
data[x]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %%
data[np.logical_and(data['Defense']>200,data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
data.shape
# Out:
# (800, 12)

# %%
print(data['Type 1'].value_counts())
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
data[np.logical_and(data['Generation']==1,data['Type 1']=="Electric")]
# Out:
#        #        Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 30    31     Pikachu  Electric     NaN  35      55       40       50       50
# 31    32      Raichu  Electric     NaN  60      90       55       90       80
# 88    89   Magnemite  Electric   Steel  25      35       70       95       55
# 89    90    Magneton  Electric   Steel  50      60       95      120       70
# 108  109     Voltorb  Electric     NaN  40      30       50       55       55
# 109  110   Electrode  Electric     NaN  60      50       70       80       80
# 134  135  Electabuzz  Electric     NaN  65      83       57       95       85
# 146  147     Jolteon  Electric     NaN  65      65       60      110       95
# 157  158      Zapdos  Electric  Flying  90      90       85      125       90
#
#      Speed  Generation  Legendary
# 30      90           1      False
# 31     110           1      False
# 88      45           1      False
# 89      70           1      False
# ...

# %%
data
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
data.boxplot(column='Attack')

# %%
data['Attack'].max()
# Out:
# 190

# %%
data_new=data.head()

# %%
data_new
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data1=data.head()
data2=data.tail()

# %%
data3=pd.concat([data1,data2],axis=0,ignore_index=True)

# %%
data3
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
data['Type 2'].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ghost        14
# Ice          14
# Water        14
# Rock         14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data['Type 2'].fillna('empty',inplace=True)

# %%
data['Type 2'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 795    True
# 796    True
# 797    True
# 798    True
# 799    True
# Name: Type 2, Length: 800, dtype: bool

# %%
data.isnull().sum()
# Out:
# #             0
# Name          1
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
data1=data.loc[:,["Attack","Defense","Speed"]]

# %%
data1.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1487EE10>,
# ...
#       dtype=object)

# %%
data.loc[10:1:-1,"HP":"Defense"]
# Out:
#     HP  Attack  Defense
# 10  59      63       80
# 9   44      48       65
# 8   78     104       78
# 7   78     130      111
# 6   78      84       78
# 5   58      64       58
# 4   39      52       43
# 3   80     100      123
# 2   80      82       83
# 1   60      62       63

# %%
data.loc[10:1:-1,"Speed"::-1]
# Out:
#     Speed  Sp. Def  Sp. Atk  Defense  Attack  HP  Type 2 Type 1  \
# 10     58       80       65       80      63  59   empty  Water
# 9      43       64       50       65      48  44   empty  Water
# 8     100      115      159       78     104  78  Flying   Fire
# 7     100       85      130      111     130  78  Dragon   Fire
# 6     100       85      109       78      84  78  Flying   Fire
# 5      80       65       80       58      64  58   empty   Fire
# 4      65       50       60       43      52  39   empty   Fire
# 3      80      120      122      123     100  80  Poison  Grass
# 2      80      100      100       83      82  80  Poison  Grass
# 1      60       80       80       63      62  60  Poison  Grass
#
#                 Name   #
# 10         Wartortle  11
# 9           Squirtle  10
# 8   Mega Charizard Y   9
# 7   Mega Charizard X   8
# 6          Charizard   7
# 5         Charmeleon   6
# 4         Charmander   5
# 3      Mega Venusaur   4
# ...

# %%
data[data.HP>=200]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  122  Chansey  Normal  empty  250       5        5       35      105
# 261  262  Blissey  Normal  empty  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 261     55           2      False

# %%
data['Total_Power']=data.Attack+data.Defense

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire   empty  39      52       43       60       50
#
#    Speed  Generation  Legendary  Total_Power
# 0     45           1      False           98
# 1     60           1      False          125
# 2     80           1      False          165
# 3     80           1      False          223
# 4     65           1      False           95

# %%
data.drop(columns="Defense",inplace=True)

# %%
data.index.name

# %%
data.set_index(["Type 1","Type 2"],inplace=True)

# %%
data.sort_index()
# Out:
#                    #            Name   HP  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Electric  657          Joltik   50       57       50     65
#        Electric  658      Galvantula   70       97       60    108
#        Fighting  232       Heracross   80       40       95     85
#        Fighting  233  Mega Heracross   80       40      105     75
#        Fire      698        Larvesta   55       50       55     60
# ...              ...             ...  ...      ...      ...    ...
# Water  empty     656       Alomomola  165       40       45     65
#        empty     725         Froakie   41       62       44     71
#        empty     726       Frogadier   54       83       56     97
#        empty     763       Clauncher   50       58       63     44
#        empty     764       Clawitzer   71      120       89     59
#
#                  Generation  Legendary  Total_Power
# Type 1 Type 2
# Bug    Electric           5      False           97
# ...
